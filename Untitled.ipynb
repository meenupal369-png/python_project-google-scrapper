# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen as uReq
import logging
#import pymongo
import os

# %%
save_dir = "images/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebkit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.56"}

# %%
f"https://www.google.com/search?q={query}&sca_esv=fbaa7d3b9c35fdd6&udm=2&biw=1093&bih=494&sxsrf=AE3TifOF2QcNZ9eVmuWRFEy0oDUnLodGFw%3A1761044849065&ei=cWn3aPPaA8abseMP9JCvgQg&oq=&gs_lp=Egtnd3Mtd2l6LWltZyIAKgIIADIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAkjhGlAAWABwAXgAkAEAmAEAoAEAqgEAuAEByAEA-AEBmAIBoAIUqAIKmAMUkgcBMaAHALIHALgHAMIHAzMtMcgHDg&sclient=gws-wiz-img"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 f"https://www.google.com/search?q={query}&sca_esv=fbaa7d3b9c35fdd6&udm=2&biw=1093&bih=494&sxsrf=AE3TifOF2QcNZ9eVmuWRFEy0oDUnLodGFw%3A1761044849065&ei=cWn3aPPaA8abseMP9JCvgQg&oq=&gs_lp=Egtnd3Mtd2l6LWltZyIAKgIIADIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAkjhGlAAWABwAXgAkAEAmAEAoAEAqgEAuAEByAEA-AEBmAIBoAIUqAIKmAMUkgcBMaAHALIHALgHAMIHAzMtMcgHDg&sclient=gws-wiz-img"
#
# NameError: name 'query' is not defined

# %%
query = "Virat Kohli"
response = requests.get(f"https://www.google.com/search?q={query}&sca_esv=fbaa7d3b9c35fdd6&udm=2&biw=1093&bih=494&sxsrf=AE3TifOF2QcNZ9eVmuWRFEy0oDUnLodGFw%3A1761044849065&ei=cWn3aPPaA8abseMP9JCvgQg&oq=&gs_lp=Egtnd3Mtd2l6LWltZyIAKgIIADIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAjIKECMYJxjJAhjqAkjhGlAAWABwAXgAkAEAmAEAoAEAqgEAuAEByAEA-AEBmAIBoAIUqAIKmAMUkgcBMaAHALIHALgHAMIHAzMtMcgHDg&sclient=gws-wiz-img")

# %%
print(response)
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(response.content, 'html.parser')

# %%
Soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
Soup.find_all("img")
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTUeuIZo5io1o5Em7d8Pe9WaETi9ia7_spebQ-JRUx_JqI8PwU0oVCOfrWNog&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbRingo1RrH1Gbh0BrtN5IZwY9Z26xHozOpgq0bY90-xFL6bcPz3u0wD9K2As&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTjQrFsZ0q98tlpB98Rzx-0aot4sm99YLMi-8-l0FSYu4dX7GXJLLpfQ3QOZgg&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6CdrYXeLtgDB_RDu04lay4NYo8e-Wpas8IUGgf_PJymqdfWPGi0NA20Lqum8&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_HDBxn0Mz7FkqgLIIzN6sPwl2Yhp1nHGFy346SoB2e1pb5QV0KNar3DBQyjg&amp;s"/>,
# ...

# %%
images_tags =Soup.find_all("img")

# %%
images_tags
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTUeuIZo5io1o5Em7d8Pe9WaETi9ia7_spebQ-JRUx_JqI8PwU0oVCOfrWNog&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbRingo1RrH1Gbh0BrtN5IZwY9Z26xHozOpgq0bY90-xFL6bcPz3u0wD9K2As&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTjQrFsZ0q98tlpB98Rzx-0aot4sm99YLMi-8-l0FSYu4dX7GXJLLpfQ3QOZgg&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6CdrYXeLtgDB_RDu04lay4NYo8e-Wpas8IUGgf_PJymqdfWPGi0NA20Lqum8&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_HDBxn0Mz7FkqgLIIzN6sPwl2Yhp1nHGFy346SoB2e1pb5QV0KNar3DBQyjg&amp;s"/>,
# ...

# %%
len(images_tags)
# Out:
# 21

# %%
del images_tags[0]

# %%
len(images_tags)
# Out:
# 20

# %%
img_data_mongo = []

for i in images_tags:
    image_url = i['src']
    image_data = requests.get(image_url).content
    my_dict = {"index": image_url, "image": image_data}
    img_data_mongo.append(my_dict)
    with open(os.path.join(save_dir, f"{query}_{images_tags.index(i)}.jpg"),"wb")as f:
        f.write(image_data)
